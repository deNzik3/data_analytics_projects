# %% [markdown]
# <a href="https://colab.research.google.com/github/deNzik3/portfolio/blob/main/python/best_universities_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_csv('/content/cwurData.csv')

# %%
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %%
df.isna().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
 df = df[df['broad_impact'] > 0 ]

# %%
df.head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# ...

# %%
top10 = df.head(10)

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['figure.figsize'] = (12, 6)
plt.title('Top 10 universities', fontsize = 20, weight = 'heavy')
sns.barplot(x = top10.score, y = top10.institution)

# %%
data = top10['country'].value_counts()

# %%
plt.pie(data, labels = data.index, autopct = '%0.00f%%', colors = ['purple','pink'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbbfa345070>,
# ...
#  [Text(-0.8899187180267095, 0.6465637441936395, 'USA'),
#   Text(0.8899187482945414, -0.6465637025335375, 'United Kingdom')],
#  [Text(-0.48541020983275057, 0.3526711331965306, '80%'),
#   Text(0.4854102263424771, -0.3526711104728386, '20%')])

# %%
df.head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# ...

# %%
data = df.groupby(by = 'country', as_index = False, sort = True)['quality_of_education'].agg(['max','min','mean','sum']).sort_values(by = 'mean',ascending = False)

# %%
data.head(10)
# Out:
#                  max  min   mean   sum
# country
# Uruguay          367  355  361.0   722
# Colombia         367  355  361.0  1444
# Puerto Rico      367  355  361.0   722
# Thailand         367  355  361.0  2166
# Slovenia         367  355  361.0  1444
# Malaysia         367  355  361.0  2166
# Cyprus           367  355  361.0   722
# Croatia          367  355  361.0   722
# Slovak Republic  367  355  361.0   722
# Singapore        367  355  361.0  1444

# %%
df
# Out:
#       world_rank                            institution         country  \
# 200            1                     Harvard University             USA
# 201            2                    Stanford University             USA
# 202            3  Massachusetts Institute of Technology             USA
# 203            4                University of Cambridge  United Kingdom
# 204            5                   University of Oxford  United Kingdom
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
data = df.groupby(by = 'country', as_index = False, sort = True)['publications'].sum().sort_values(by = 'publications', ascending = False).head(15)
data
# Out:
#            country  publications
# 54             USA        189031
# 8            China         98291
# 28           Japan         96533
# 57  United Kingdom         56448
# 17          France         54483
# 48           Spain         45281
# 27           Italy         44665
# 18         Germany         41786
# 47     South Korea         39993
# 6           Canada         26775
# 51          Taiwan         26198
# 1        Australia         23960
# 4           Brazil         22399
# 23           India         20956
# 53          Turkey         14614

# %%
plt.title('Most publications by country', fontsize = 20, weight = 'heavy')

sns.barplot(data = data, x = 'publications', y = 'country', color = 'purple')

# %%
df.head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# ...

# %%
df.year.value_counts()
# Out:
# 2014    1000
# 2015    1000
# Name: year, dtype: int64

# %%
top10_2015 = df[df['year'] == 2015].head(10)

# %%
plt.figure(figsize = (20,10))
fig, (ax1,ax2) = plt.subplots(1,2)


plt.subplots_adjust(wspace = .9)

ax1.set_title('Top 10 in 2014',fontsize = 20, weight = 'heavy')
ax2.set_title('Top 10 in 2015',fontsize = 20, weight = 'heavy')


year_2014 = ax1.barh(top10.institution, top10.score,color = 'green')
year_2015 = ax2.barh(top10_2015.institution, top10_2015.score, color = 'purple')

# %%
df.head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# ...

# %%
data14 = df[df['year'] == 2014].groupby(by = 'country', as_index = False, sort = True)['patents'].sum().sort_values(by = 'patents', ascending = False).head(15)
data15 = df[df['year'] == 2015].groupby(by = 'country', as_index = False, sort = True)['patents'].sum().sort_values(by = 'patents', ascending = False).head(15)
data14
# Out:
#            country  patents
# 54             USA    79126
# 8            China    41275
# 57  United Kingdom    28788
# 27           Italy    28784
# 28           Japan    27271
# 17          France    25156
# 18         Germany    23515
# 51          Taiwan    17240
# 48           Spain    17139
# 6           Canada    14559
# 1        Australia    13457
# 4           Brazil    10799
# 49          Sweden     7907
# 23           India     7882
# 53          Turkey     7270

# %%
plt.subplots_adjust(wspace = .6)
fig, (ax1,ax2) = plt.subplots(1,2)
plt.figure(figsize = (20,10))

fig.autofmt_xdate(rotation=70)

ax1.set_title('2014',fontsize = 20, weight = 'heavy')
ax2.set_title('2015', fontsize = 20, weight = 'heavy')



year_2014 = ax1.bar(data14.country, data14.patents, color = 'orange')
year_2015 = ax2.bar(data15.country, data15.patents, color = 'purple')

# %%
df.head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# ...

# %%
data = df.groupby(by = ['country','year'], as_index = True, sort = True)['score'].agg(['max','min','mean']).sort_values(by = 'max',ascending = False)

# %%
data.reset_index(inplace= True )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    118 non-null    int64
#  1   country  118 non-null    object
#  2   year     118 non-null    int64
#  3   max      118 non-null    float64
#  4   min      118 non-null    float64
#  5   mean     118 non-null    float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 5.7+ KB

# %%
data['2015'] = data[data['year'] == 2015]['mean']
data['2014'] = data[data['year'] == 2014]['mean']

# %%
data = df.groupby(by = 'country', as_index = False, sort = True)['patents','score'].sum().sort_values(by = 'score', ascending = False).head(15)
data
# Out:
# <ipython-input-103-5bbd2170d4d7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by = 'country', as_index = False, sort = True)['patents','score'].sum().sort_values(by = 'score', ascending = False).head(15)
#            country  patents     score
# 54             USA   163268  23072.37
# 8            China    88472   7513.76
# 28           Japan    55886   6892.28
# 57  United Kingdom    59896   6220.84
# 18         Germany    47751   5109.16
# 17          France    53362   4574.81
# 27           Italy    60373   4269.13
# 48           Spain    35327   3644.26
# 47     South Korea    13433   3228.23
# 6           Canada    32007   3057.09
# 1        Australia    27179   2480.30
# 51          Taiwan    34139   2070.57
# 4           Brazil    23008   1612.12
# 23           India    17810   1386.11
# 33     Netherlands    10362   1256.46

# %%
plt.title('The relationship between score and patents', fontsize = 20, weight = 'heavy')
sns.lineplot(data.patents, data.score, color = 'purple')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data = df.groupby(by = 'country', as_index = False, sort = True)['quality_of_education','publications' ].sum().sort_values(by = 'publications', ascending = False)
# Out:
# <ipython-input-120-ce2aa210f3b7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data = df.groupby(by = 'country', as_index = False, sort = True)['quality_of_education','publications' ].sum().sort_values(by = 'publications', ascending = False)

# %%
plt.title('The relationship between publications and quality of education', fontsize = 20, weight = 'heavy')
sns.lineplot(data.quality_of_education, data.publications, color = 'blue')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df
# Out:
#       world_rank                            institution         country  \
# 200            1                     Harvard University             USA
# 201            2                    Stanford University             USA
# 202            3  Massachusetts Institute of Technology             USA
# 203            4                University of Cambridge  United Kingdom
# 204            5                   University of Oxford  United Kingdom
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...
